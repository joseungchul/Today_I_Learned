# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
#from plotnine import * 
import plotnine
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-60c447e9f0c3> in <module>
#       1 #from plotnine import *
# ----> 2 import plotnine
#
# ~\anaconda3\lib\site-packages\plotnine\__init__.py in <module>
#       7 from .coords import *               # noqa: F401,F403,E261
#       8 from .geoms import *                # noqa: F401,F403,E261
# ----> 9 from .stats import *                # noqa: F401,F403,E261
#      10 from .scales import *               # noqa: F401,F403,E261
#      11 from .facets import *               # noqa: F401,F403,E261
#
# ~\anaconda3\lib\site-packages\plotnine\stats\__init__.py in <module>
#       5 from .stat_boxplot import stat_boxplot
#       6 from .stat_density import stat_density
# ----> 7 from .stat_density_2d import stat_density_2d
#       8 from .stat_ecdf import stat_ecdf
#       9 from .stat_ellipse import stat_ellipse
#
# ~\anaconda3\lib\site-packages\plotnine\stats\stat_density_2d.py in <module>
#       6 from ..doctools import document
#       7 from .stat import stat
# ----> 8 from .density import kde, get_var_type
#       9
#      10
#
# ~\anaconda3\lib\site-packages\plotnine\stats\density.py in <module>
#      18 # Not core dependency
#      19 with suppress(ImportError):
# ---> 20     from sklearn.neighbors import KernelDensity
#      21
#      22
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\__init__.py in <module>
#      15 from ._kde import KernelDensity
#      16 from ._lof import LocalOutlierFactor
# ---> 17 from ._nca import NeighborhoodComponentsAnalysis
#      18 from ._base import VALID_METRICS, VALID_METRICS_SPARSE
#      19
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\_nca.py in <module>
#      20 from ..base import BaseEstimator, TransformerMixin
#      21 from ..preprocessing import LabelEncoder
# ---> 22 from ..decomposition import PCA
#      23 from ..utils.multiclass import check_classification_targets
#      24 from ..utils.random import check_random_state
#
# ~\anaconda3\lib\site-packages\sklearn\decomposition\__init__.py in <module>
#      15 with warnings.catch_warnings():
#      16     warnings.simplefilter("ignore", category=FutureWarning)
# ---> 17     from .dict_learning import dict_learning
#      18
#      19
#
# ~\anaconda3\lib\site-packages\sklearn\decomposition\dict_learning.py in <module>
#       2 # THIS FILE WAS AUTOMATICALLY GENERATED BY deprecated_modules.py
#       3 import sys
# ----> 4 from . import _dict_learning
#       5 from ..externals._pep562 import Pep562
#       6 from ..utils.deprecation import _raise_dep_warning_if_not_pytest
#
# ~\anaconda3\lib\site-packages\sklearn\decomposition\_dict_learning.py in <module>
#      19 from ..utils.extmath import randomized_svd, row_norms
#      20 from ..utils.validation import check_is_fitted
# ---> 21 from ..linear_model import Lasso, orthogonal_mp_gram, LassoLars, Lars
#      22
#      23
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\__init__.py in <module>
#      12 from ._least_angle import (Lars, LassoLars, lars_path, lars_path_gram, LarsCV,
#      13                            LassoLarsCV, LassoLarsIC)
# ---> 14 from ._coordinate_descent import (Lasso, ElasticNet, LassoCV, ElasticNetCV,
#      15                                   lasso_path, enet_path, MultiTaskLasso,
#      16                                   MultiTaskElasticNet, MultiTaskElasticNetCV,
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py in <module>
#      25 from ..utils.validation import column_or_1d
#      26
# ---> 27 from . import _cd_fast as cd_fast
#      28
#      29
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_cd_fast.cp37-win_amd64.pyd in init sklearn.linear_model._cd_fast()
#
# AttributeError: type object 'sklearn.linear_model._cd_fast.array' has no attribute '__reduce_cython__'

# %%
import matplotlib as mpl

# %%
import pandas as pd
import numpy as np
from plotnine import *
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-5c5b7273d1bf> in <module>
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 from plotnine import *
#
# ~\anaconda3\lib\site-packages\plotnine\__init__.py in <module>
#       7 from .coords import *               # noqa: F401,F403,E261
#       8 from .geoms import *                # noqa: F401,F403,E261
# ----> 9 from .stats import *                # noqa: F401,F403,E261
#      10 from .scales import *               # noqa: F401,F403,E261
#      11 from .facets import *               # noqa: F401,F403,E261
#
# ~\anaconda3\lib\site-packages\plotnine\stats\__init__.py in <module>
#       5 from .stat_boxplot import stat_boxplot
#       6 from .stat_density import stat_density
# ----> 7 from .stat_density_2d import stat_density_2d
#       8 from .stat_ecdf import stat_ecdf
#       9 from .stat_ellipse import stat_ellipse
#
# ~\anaconda3\lib\site-packages\plotnine\stats\stat_density_2d.py in <module>
#       6 from ..doctools import document
#       7 from .stat import stat
# ----> 8 from .density import kde, get_var_type
#       9
#      10
#
# ~\anaconda3\lib\site-packages\plotnine\stats\density.py in <module>
#      18 # Not core dependency
#      19 with suppress(ImportError):
# ---> 20     from sklearn.neighbors import KernelDensity
#      21
#      22
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\__init__.py in <module>
#      15 from ._kde import KernelDensity
#      16 from ._lof import LocalOutlierFactor
# ---> 17 from ._nca import NeighborhoodComponentsAnalysis
#      18 from ._base import VALID_METRICS, VALID_METRICS_SPARSE
#      19
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\_nca.py in <module>
#      20 from ..base import BaseEstimator, TransformerMixin
#      21 from ..preprocessing import LabelEncoder
# ---> 22 from ..decomposition import PCA
#      23 from ..utils.multiclass import check_classification_targets
#      24 from ..utils.random import check_random_state
#
# ~\anaconda3\lib\site-packages\sklearn\decomposition\__init__.py in <module>
#      15 with warnings.catch_warnings():
#      16     warnings.simplefilter("ignore", category=FutureWarning)
# ---> 17     from .dict_learning import dict_learning
#      18
#      19
#
# ~\anaconda3\lib\site-packages\sklearn\decomposition\dict_learning.py in <module>
#       2 # THIS FILE WAS AUTOMATICALLY GENERATED BY deprecated_modules.py
#       3 import sys
# ----> 4 from . import _dict_learning
#       5 from ..externals._pep562 import Pep562
#       6 from ..utils.deprecation import _raise_dep_warning_if_not_pytest
#
# ~\anaconda3\lib\site-packages\sklearn\decomposition\_dict_learning.py in <module>
#      19 from ..utils.extmath import randomized_svd, row_norms
#      20 from ..utils.validation import check_is_fitted
# ---> 21 from ..linear_model import Lasso, orthogonal_mp_gram, LassoLars, Lars
#      22
#      23
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\__init__.py in <module>
#      12 from ._least_angle import (Lars, LassoLars, lars_path, lars_path_gram, LarsCV,
#      13                            LassoLarsCV, LassoLarsIC)
# ---> 14 from ._coordinate_descent import (Lasso, ElasticNet, LassoCV, ElasticNetCV,
#      15                                   lasso_path, enet_path, MultiTaskLasso,
#      16                                   MultiTaskElasticNet, MultiTaskElasticNetCV,
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py in <module>
#      25 from ..utils.validation import column_or_1d
#      26
# ---> 27 from . import _cd_fast as cd_fast
#      28
#      29
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_cd_fast.cp37-win_amd64.pyd in init sklearn.linear_model._cd_fast()
#
# AttributeError: type object 'sklearn.linear_model._cd_fast.array' has no attribute '__reduce_cython__'
